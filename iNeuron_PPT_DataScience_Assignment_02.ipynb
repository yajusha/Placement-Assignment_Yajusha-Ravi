# %%
1. To calculate the mean sales for each region, you need to sum up the sales in each region and then divide by the number of data points. Here are the calculations:

   For Region A: [10, 15, 12, 8, 14]
   Mean = (10 + 15 + 12 + 8 + 14) / 5 = 59 / 5 = 11.8

   For Region B: [18, 20, 16, 22, 25]
   Mean = (18 + 20 + 16 + 22 + 25) / 5 = 101 / 5 = 20.2

   Therefore, the mean sales for Region A is 11.8 and for Region B is 20.2.

2. To calculate the mode of the survey responses, you need to find the value(s) that appear most frequently. Here are the calculations:

   Survey responses: [4, 5, 2, 3, 5, 4, 3, 2, 4, 5]
   Mode = 4, 5 (as they both appear three times)

   Therefore, the mode of the survey responses is 4 and 5.

3. To calculate the median salary for each department, you need to arrange the salaries in ascending order and find the middle value. Here are the calculations:

   Department A: [5000, 6000, 5500, 7000]
   Arranged in ascending order: [5000, 5500, 6000, 7000]
   Median = (5500 + 6000) / 2 = 11500 / 2 = 5750

   Department B: [4500, 5500, 5800, 6000, 5200]
   Arranged in ascending order: [4500, 5200, 5500, 5800, 6000]
   Median = 5500

   Therefore, the median salary for Department A is 5750 and for Department B is 5500.

4. To calculate the range of the stock prices, you need to find the difference between the maximum and minimum values. Here are the calculations:

   Stock prices: [25.5, 24.8, 26.1, 25.3, 24.9]
   Range = maximum value - minimum value
         = 26.1 - 24.8
         = 1.3

   Therefore, the range of the stock prices is 1.3.

5. To perform a t-test to determine if there is a significant difference in the mean scores between two groups, you can use a two-sample t-test. Here are the steps:

   Group A: [85, 90, 92, 88, 91]
   Group B: [82, 88, 90, 86, 87]

   Step 1: Calculate the means for each group.
   Mean of Group A = (85 + 90 + 92 + 88 + 91) / 5 = 446 / 5 = 89.2
   Mean of Group B = (82 + 88 + 90 + 86 + 87) / 5 = 433 / 5 = 86.6

   Step 2: Calculate the standard deviations for each group.
   Standard deviation of Group A = sqrt(((85 - 89.2)^2 + (90 - 89.2)^2 + (92 - 89.2)^2 + (88 - 89.2)^2 + (91 - 89.2)^2) / 4) = 2.69
   Standard deviation of Group B = sqrt(((82 - 86.6)^2 + (88 - 86.6)^2 + (90 - 86.6)^2 + (86 - 86.6)^2 + (87 - 86.6)^2) / 4) = 2.19

   Step 3: Calculate the t-statistic.
   t = (mean of Group A - mean of Group B) / sqrt((standard deviation of Group A^2 / sample size of Group A) + (standard deviation of Group B^2 / sample size of Group B))
   t = (89.2 - 86.6) / sqrt((2.69^2 / 5) + (2.19^2 / 5))
   t = 2.6 / sqrt(3.5 + 1.9)
   t = 2.6 / sqrt(5.4)
   t ≈ 1.16

   Step 4: Compare the calculated t-statistic with the critical value from the t-distribution table with the degrees of freedom (n1 + n2 - 2). If the calculated t-statistic is greater than the critical value, there is a significant difference between the means of the two groups.

   For a given significance level (e.g., α = 0.05), the critical value for a two-tailed test with 8 degrees of freedom (5 + 5 - 2) is approximately ±2.31.

   Since |t| = 1.16 < 2.31, we fail to reject the null hypothesis. There is not enough evidence to suggest a significant difference in the mean scores between Group A and Group B.

6. To calculate the correlation coefficient between advertising expenditure and sales, you can use the Pearson correlation coefficient formula. Here are the calculations:

   Advertising Expenditure (in thousands): [10, 15, 12, 8, 14]
   Sales (in thousands): [25, 30, 28, 20, 26]

   Step 1: Calculate the means for each variable.
   Mean of Advertising Expenditure = (10 + 15 + 12 + 8 + 14) / 5 = 59 / 5 = 11.8
   Mean of Sales = (25 + 30 + 28 + 20 + 26) / 5 = 129 / 5 = 25.8

   Step 2: Calculate the standard deviations for each variable.
   Standard deviation of Advertising Expenditure = sqrt(((10 - 11.8)^2 + (15 - 11.8)^2 + (12 - 11.8)^2 + (8 - 11.8)^2 + (14 - 11.8)^2) / 4) = 2.69
   Standard deviation of Sales = sqrt(((25 - 25.8)^2 + (30 - 25.8)^2 + (28 - 25.8)^2 + (20 - 25.8)^2 + (26 - 25.8)^2) / 4) = 2.69

   Step 3: Calculate the covariance between the two variables.
   Covariance = ((10 - 11.8) * (25 - 25.8) + (15 - 11.8) * (30 - 25.8) + (12 - 11.8) * (28 - 25.8) + (8 - 11.8) * (20 - 25.8)
7. To calculate the standard deviation of the heights, you can use the following steps:

   Heights: [160, 170, 165, 155, 175, 180, 170]

   Step 1: Calculate the mean height.
   Mean = (160 + 170 + 165 + 155 + 175 + 180 + 170) / 7 = 1175 / 7 = 167.8571

   Step 2: Calculate the deviation of each height from the mean.
   Deviations: [-7.8571, 2.1429, -2.8571, -12.8571, 7.1429, 12.1429, 2.1429]

   Step 3: Square each deviation.
   Squared deviations: [61.5951, 4.5918, 8.1633, 165.3061, 51.0204, 147.9592, 4.5918]

   Step 4: Calculate the mean of the squared deviations.
   Mean of squared deviations = (61.5951 + 4.5918 + 8.1633 + 165.3061 + 51.0204 + 147.9592 + 4.5918) / 7 = 443.2276 / 7 = 63.3182

   Step 5: Take the square root of the mean of squared deviations.
   Standard deviation = sqrt(63.3182) ≈ 7.96

   Therefore, the standard deviation of the heights is approximately 7.96.

8. To perform a linear regression analysis to predict job satisfaction based on employee tenure, you can use the following steps:

   Employee Tenure (in years): [2, 3, 5, 4, 6, 2, 4]
   Job Satisfaction (on a scale of 1 to 10): [7, 8, 6, 9, 5, 7, 6]

   Step 1: Calculate the means for both variables.
   Mean of Employee Tenure = (2 + 3 + 5 + 4 + 6 + 2 + 4) / 7 = 26 / 7 = 3.71
   Mean of Job Satisfaction = (7 + 8 + 6 + 9 + 5 + 7 + 6) / 7 = 48 / 7 = 6.86

   Step 2: Calculate the deviations of each variable from the mean.
   Deviations of Employee Tenure: [-1.71, -0.71, 1.29, 0.29, 2.29, -1.71, 0.29]
   Deviations of Job Satisfaction: [0.14, 1.14, -0.86, 2.14, -1.86, 0.14, -0.86]

   Step 3: Calculate the product of deviations for each pair of data points.
   Products of deviations: [2.9234, -0.8086, -1.1134, 0.6206, -4.2066, -0.2406, -0.2506]

   Step 4: Calculate the sum of the products of deviations.
   Sum of products of deviations = 2.9234 - 0.8086 - 1.1134 + 0.6206 - 4.2066 - 0.2406 - 0.2506 = -2.0756

   Step 5: Calculate the sum of squared deviations for Employee Tenure.
   Sum of squared deviations for Employee Tenure = 1.71^2 + 0.71^2 + 1.29^2 + 0.29^2 + 2.29^2 + 1.71^2 + 0.29^2 = 16.43

   Step 6: Perform the linear regression calculations.
   Slope (b) = Sum of products of deviations / Sum of squared deviations for Employee Tenure = -2.0756 / 16.43 ≈ -0.126
   Intercept (a) = Mean of Job Satisfaction - (Slope * Mean of Employee Tenure) = 6.86 - (-0.126 * 3.71) ≈ 7.36

   Therefore, the linear regression equation to predict job satisfaction based on employee tenure is: Job Satisfaction = 7.36 - 0.126 * Employee Tenure.

9. To perform an analysis of variance (ANOVA) to determine if there is a significant difference in the mean recovery times between the two medications, you can use the following steps:

   Medication A: [10, 12, 14, 11, 13]
   Medication B: [15, 17, 16, 14, 18]

   Step 1: Calculate the means for each medication group.
   Mean of Medication A = (10 + 12 + 14 + 11 + 13) / 5 = 60 / 5 = 12
   Mean of Medication B = (15 + 17 + 16 + 14 + 18) / 5 = 80 / 5 = 16

   Step 2: Calculate the sum of squares within groups (SSW).
   SSW = Sum of squared deviations within Medication A + Sum of squared deviations within Medication B

   Sum of squared deviations within Medication A = (10 - 12)^2 + (12 - 12)^2 + (14 - 12)^2 + (11 - 12)^2 + (13 - 12)^2 = 2 + 0 + 2 + 1 + 1 = 6
   Sum of squared deviations within Medication B = (15 - 16)^2 + (17 - 16)^2 + (16 - 16)^2 + (14 - 16)^2 + (18 - 16)^2 = 1 + 1 + 0 + 4 + 4 = 10

   SSW = 6 + 10 = 16

   Step 3: Calculate the sum of squares between groups (SSB).
   SSB = (Mean of Medication A - Overall Mean)^2 * Sample size of Medication A + (Mean of Medication B - Overall Mean)^2 * Sample size of Medication B

   Overall Mean = (Mean of Medication A * Sample size of Medication A + Mean of Medication B * Sample size of Medication B) / Total sample size
                = (12 * 5 + 16 * 5) / 10 = (60 + 80) / 10 = 140 / 10 = 14

   SSB = (12 - 14)^2 * 5 + (16 - 14)^2 * 5 = 4 * 5 + 4 * 5 = 20 + 20 = 40

   Step 4: Calculate the degrees of freedom (df) for SSW and SSB.
   df SSW = Total sample size - Number of groups = 10 - 2 = 8
   df S
